# %%
from pathlib import Path

import numpy as np

from src.analysis import Analysis
from src.cutting import Cut

DTA_PATH = Path("/mnt/D/data/DTA_outputs/2024-09-19/")
# DTA_PATH = Path("/eos/home-k/kghorban/DTA_OUT/2024-02-05/")
DO_SYS = True

# CUTS & SELECTIONS
# ========================================================================
pass_presel = Cut(
    r"Pass preselection",
    r"(passReco == 1) && (TauBaselineWP == 1) && (abs(TauCharge) == 1) && passMetTrigger"
    r"&& ((MatchedTruthParticle_isTau + MatchedTruthParticle_isElectron + MatchedTruthParticle_isMuon + MatchedTruthParticle_isPhoton) <= 1)"
    r"&& ((TauNCoreTracks == 1) || (TauNCoreTracks == 3))",
)
pass_taupt170 = Cut(
    r"$p_T^\tau > 170$",
    r"TauPt > 170",
)
pass_mtw150 = Cut(
    r"$m_T^W > 150$",
    r"MTW > 150",
)
pass_loose = Cut(
    r"\mathrm{Pass Loose ID}",
    r"(TauBDTEleScore > 0.05) && "
    r"((TauRNNJetScore > 0.15) * (TauNCoreTracks == 1) + (TauRNNJetScore > 0.25) * (TauNCoreTracks == 3))",
)
fail_loose = Cut(
    r"\mathrm{Fail Loose ID}",
    r"(TauBDTEleScore > 0.05) && "
    r"(TauRNNJetScore > 0.01) && "
    r"!((TauRNNJetScore > 0.15) * (TauNCoreTracks == 1) + (TauRNNJetScore > 0.25) * (TauNCoreTracks == 3))",
)
pass_medium = Cut(
    r"\mathrm{Pass Medium ID}",
    r"(TauBDTEleScore > 0.1) && "
    r"((TauRNNJetScore > 0.25) * (TauNCoreTracks == 1) + (TauRNNJetScore > 0.4) * (TauNCoreTracks == 3))",
)
fail_medium = Cut(
    r"\mathrm{Fail Medium ID}",
    r"(TauBDTEleScore > 0.1) && "
    r"(TauRNNJetScore > 0.01) && "
    r"!((TauRNNJetScore > 0.25) * (TauNCoreTracks == 1) + (TauRNNJetScore > 0.4) * (TauNCoreTracks == 3))",
)
pass_tight = Cut(
    r"\mathrm{Pass Tight ID}",
    r"(TauBDTEleScore > 0.15) && "
    r"((TauRNNJetScore > 0.4) * (TauNCoreTracks == 1) + (TauRNNJetScore > 0.55) * (TauNCoreTracks == 3))",
)
fail_tight = Cut(
    r"\mathrm{Fail Tight ID}",
    r"(TauBDTEleScore > 0.15) && "
    r"(TauRNNJetScore > 0.01) && "
    r"!((TauRNNJetScore > 0.4) * (TauNCoreTracks == 1) + (TauRNNJetScore > 0.55) * (TauNCoreTracks == 3))",
)
pass_met150 = Cut(
    r"$E_T^{\mathrm{miss}} > 150$",
    r"MET_met > 150",
)
pass_100met = Cut(
    r"$E_T^{\mathrm{miss}} < 100$",
    r"MET_met < 100",
)
pass_1prong = Cut(
    "1-prong",
    "TauNCoreTracks == 1",
)
pass_3prong = Cut(
    "3-prong",
    "TauNCoreTracks == 3",
)
pass_truetau = Cut(
    # this is a multijet background estimation. Tau is "True" in this case if it is a lepton
    r"True Tau",
    "MatchedTruthParticle_isHadronicTau == true || MatchedTruthParticle_isMuon == true || MatchedTruthParticle_isElectron == true",
)
fail_truetau = Cut(
    r"Fake Tau",
    "!(MatchedTruthParticle_isHadronicTau == true || MatchedTruthParticle_isMuon == true || MatchedTruthParticle_isElectron == true)",
)

# selections
selections_loose: dict[str, list[Cut]] = {
    "loose_SR_passID": [
        pass_presel,
        pass_taupt170,
        pass_mtw150,
        pass_loose,
        pass_met150,
    ],
    "loose_SR_failID": [
        pass_presel,
        pass_taupt170,
        pass_mtw150,
        fail_loose,
        pass_met150,
    ],
    "loose_CR_passID": [
        pass_presel,
        pass_taupt170,
        pass_mtw150,
        pass_loose,
        pass_100met,
    ],
    "loose_CR_failID": [
        pass_presel,
        pass_taupt170,
        pass_mtw150,
        fail_loose,
        pass_100met,
    ],
}
selections_medium: dict[str, list[Cut]] = {
    "medium_SR_passID": [
        pass_presel,
        pass_taupt170,
        pass_mtw150,
        pass_medium,
        pass_met150,
    ],
    "medium_SR_failID": [
        pass_presel,
        pass_taupt170,
        pass_mtw150,
        fail_medium,
        pass_met150,
    ],
    "medium_CR_passID": [
        pass_presel,
        pass_taupt170,
        pass_mtw150,
        pass_medium,
        pass_100met,
    ],
    "medium_CR_failID": [
        pass_presel,
        pass_taupt170,
        pass_mtw150,
        fail_medium,
        pass_100met,
    ],
}
selections_tight: dict[str, list[Cut]] = {
    "tight_SR_passID": [
        pass_presel,
        pass_taupt170,
        pass_mtw150,
        pass_tight,
        pass_met150,
    ],
    "tight_SR_failID": [
        pass_presel,
        pass_taupt170,
        pass_mtw150,
        fail_tight,
        pass_met150,
    ],
    "tight_CR_passID": [
        pass_presel,
        pass_taupt170,
        pass_mtw150,
        pass_tight,
        pass_100met,
    ],
    "tight_CR_failID": [
        pass_presel,
        pass_taupt170,
        pass_mtw150,
        fail_tight,
        pass_100met,
    ],
}
selections = selections_loose | selections_medium | selections_tight

# define selection for MC samples
selections_list = list(selections.keys())
selections_cuts = list(selections.values())
for selection, cut_list in zip(selections_list, selections_cuts):
    selections[f"trueTau_{selection}"] = cut_list + [pass_truetau]
    # define selections for 1- or 3- tau prongs
    for cutstr, cut_name in [
        ("TauNCoreTracks == 1", "1prong"),
        ("TauNCoreTracks == 3", "3prong"),
    ]:
        selections[f"{cut_name}_{selection}"] = cut_list + [Cut(cut_name, cutstr)]
        selections[f"trueTau_{cut_name}_{selection}"] = cut_list + [
            pass_truetau,
            Cut(cut_name, cutstr),
        ]
# for data
selections_notruth = {n: s for n, s in selections.items() if not n.startswith("trueTau_")}

# to compare fakes
selections |= {
    "fakeTau_loose_SR_passID": [
        pass_presel,
        pass_taupt170,
        pass_mtw150,
        pass_loose,
        pass_met150,
        fail_truetau,
    ],
    "fakeTau_medium_SR_passID": [
        pass_presel,
        pass_taupt170,
        pass_mtw150,
        pass_loose,
        pass_met150,
        fail_truetau,
    ],
    "fakeTau_tight_SR_passID": [
        pass_presel,
        pass_taupt170,
        pass_mtw150,
        pass_loose,
        pass_met150,
        fail_truetau,
    ],
}

# VARIABLES
# ========================================================================
wanted_variables = {
    "TauEta",
    "TauPhi",
    "TauPt",
    "MET_met",
    "MET_phi",
    "MTW",
    "TauRNNJetScore",
    "TauBDTEleScore",
    # "DeltaPhi_tau_met",
    "TauNCoreTracks",
}
measurement_vars_mass = [
    "TauPt",
    "MTW",
    "MET_met",
]
measurement_vars_unitless = [
    "TauEta",
    "TauPhi",
    "TauBDTEleScore",
    "TauRNNJetScore",
    # "DeltaPhi_tau_met",
    "TauNCoreTracks",
]
measurement_vars = measurement_vars_unitless + measurement_vars_mass
NOMINAL_NAME = "T_s1thv_NOMINAL"

datasets: dict[str, dict] = {
    # DATA
    # ====================================================================
    "data": {
        # "data_path": DTA_PATH / "*data17*/*.root",
        "data_path": Path("/data/DTA_outputs/2024-03-05/*data17*/*.root"),
        "label": "data",
        "is_data": True,
        "selections": selections_notruth,
        "snapshot": {"selections": selections_notruth, "systematics": NOMINAL_NAME},
        # "rerun": True,
        # "regen_histograms": True,
    },
    # SIGNAL
    # ====================================================================
    "wtaunu": {
        "data_path": {
            "lm_cut": DTA_PATH / "*Sh_2211_Wtaunu_*_maxHTpTV2*/*.root",
            "full": DTA_PATH / "*Sh_2211_Wtaunu_mW_120*/*.root",
        },
        "hard_cut": {"lm_cut": "TruthBosonM < 120"},
        "label": r"$W\rightarrow\tau\nu$",
        "is_signal": True,
        "snapshot": {"selections": list(selections.keys()), "systematics": NOMINAL_NAME},
        "selections": selections,
    },
    # BACKGROUNDS
    # ====================================================================
    # W -> light lepton
    "wlnu": {
        "data_path": {
            "lm_cut": [
                DTA_PATH / "*Sh_2211_Wmunu_maxHTpTV2*/*.root",
                DTA_PATH / "*Sh_2211_Wenu_maxHTpTV2*/*.root",
            ],
            "full": [
                DTA_PATH / "*Sh_2211_Wmunu_mW_120*/*.root",
                DTA_PATH / "*Sh_2211_Wenu_mW_120*/*.root",
            ],
        },
        "hard_cut": {"lm_cut": "TruthBosonM < 120"},
        "label": r"$W\rightarrow (e/\mu)\nu$",
        "snapshot": {"selections": list(selections.keys()), "systematics": NOMINAL_NAME},
        "selections": selections,
    },
    # Z -> ll
    "zll": {
        "data_path": {
            "lm_cut": [
                DTA_PATH / "*Sh_2211_Ztautau_*_maxHTpTV2*/*.root",
                DTA_PATH / "*Sh_2211_Zee_maxHTpTV2*/*.root",
                DTA_PATH / "*Sh_2211_Zmumu_maxHTpTV2*/*.root",
            ],
            "full": [
                DTA_PATH / "*Sh_2211_Ztautau_mZ_120*/*.root",
                DTA_PATH / "*Sh_2211_Zmumu_mZ_120*/*.root",
                DTA_PATH / "*Sh_2211_Zee_mZ_120*/*.root",
                DTA_PATH / "*Sh_2211_Znunu_pTV2*/*.root",
            ],
        },
        "hard_cut": {"lm_cut": "TruthBosonM < 120"},
        "label": r"$Z\rightarrow (l/\nu)(l/\nu)$",
        "snapshot": {"selections": list(selections.keys()), "systematics": NOMINAL_NAME},
        "selections": selections,
    },
    "top": {
        "data_path": [
            DTA_PATH / "*PP8_singletop*/*.root",
            DTA_PATH / "*PP8_tchan*/*.root",
            DTA_PATH / "*PP8_Wt_DR_dilepton*/*.root",
            DTA_PATH / "*PP8_ttbar_hdamp258p75*/*.root",
        ],
        "label": "Top",
        "snapshot": {"selections": list(selections.keys()), "systematics": NOMINAL_NAME},
        "selections": selections,
    },
    # DIBOSON
    "diboson": {
        "data_path": [
            DTA_PATH / "*Sh_2212_llll*/*.root",
            DTA_PATH / "*Sh_2212_lllv*/*.root",
            DTA_PATH / "*Sh_2212_llvv*/*.root",
            DTA_PATH / "*Sh_2212_lvvv*/*.root",
            DTA_PATH / "*Sh_2212_vvvv*/*.root",
            DTA_PATH / "*Sh_2211_ZqqZll*/*.root",
            DTA_PATH / "*Sh_2211_ZbbZll*/*.root",
            DTA_PATH / "*Sh_2211_WqqZll*/*.root",
            DTA_PATH / "*Sh_2211_WlvWqq*/*.root",
            DTA_PATH / "*Sh_2211_WlvZqq*/*.root",
            DTA_PATH / "*Sh_2211_WlvZbb*/*.root",
        ],
        "label": "Diboson",
        "snapshot": {"selections": list(selections.keys()), "systematics": NOMINAL_NAME},
        "selections": selections,
    },
}
# Out:
# C system headers (glibc/Xcode/Windows SDK) must be installed.
# In file included from input_line_4:36:
# /home/keanu/micromamba/envs/framework_env/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/12.3.0/cassert:44:10: fatal error: 'assert.h' file not found
# #include <assert.h>
#          ^~~~~~~~~~
# input_line_35:1:10: fatal error: 'dlfcn.h' file not found
# #include "dlfcn.h"
#          ^~~~~~~~~
# Applying ATLAS style settings...

# %%
n_edges = 16
analysis = Analysis(
    datasets,
    year=2017,
    # rerun=True,
    # regen_histograms=True,
    do_systematics=DO_SYS,
    # regen_metadata=True,
    # output_dir="/eos/home-k/kghorban/framework_outputs/analysis_main",
    ttree=NOMINAL_NAME,
    analysis_label="analysis_main",
    log_level=10,
    log_out="both",
    extract_vars=wanted_variables,
    import_missing_columns_as_nan=True,
    binnings={
        "": {
            "MTW": np.geomspace(150, 1000, n_edges),
            "TauPt": np.geomspace(170, 1000, n_edges),
            "TauEta": np.linspace(-2.5, 2.5, n_edges),
            "EleEta": np.linspace(-2.5, 2.5, n_edges),
            "MuonEta": np.linspace(-2.5, 2.5, n_edges),
            "MET_met": np.geomspace(150, 1000, n_edges),
            "DeltaPhi_tau_met": np.linspace(0, 3.5, n_edges),
            "TauPt_div_MET": np.linspace(0, 3, 21),
            "TauRNNJetScore": np.linspace(0, 1, 36),
            "TauBDTEleScore": np.linspace(0, 1, 36),
            "TauNCoreTracks": np.linspace(0, 4, 5),
            "TruthTauPt": np.geomspace(1, 1000, 21),
        },
        ".*_CR_.*ID": {
            "MET_met": np.geomspace(1, 100, n_edges),
        },
    },
)
base_plotting_dir = analysis.paths.plot_dir
all_samples = [analysis.data_sample] + analysis.mc_samples
mc_samples = analysis.mc_samples
for mc in mc_samples:
    analysis[mc].calculate_systematic_uncertainties()
# Out:
# Set global luminosity scale to 44307.4 pb-1
# Loaded metadata cache from /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/dsid_meta_cache.json
# Declared metadata maps in ROOT
#
# ==============================================
# ======== INITIALISING DATASET 'data' =========
# ==============================================
# No systematic uncertainties for data!
#
# DEBUG DATASET OPTIONS:
# ----------------------------
# Input ROOT file(s):  {'default': PosixPath('/data/DTA_outputs/2024-03-05/*data17*/*.root')}
# Hard cut(s) applied: {}
# Defined subsamples:
# 	- default
# Defined systematics:
# 	- T_s1thv_NOMINAL
# Defined TTree(s): {'T_s1thv_NOMINAL'}
# Variables to pull from files:
# 	- TauPhi
# 	- TauNCoreTracks
# 	- MET_met
# 	- TauCharge
# 	- TauBDTEleScore
# 	- MET_phi
# 	- MatchedTruthParticle_isPhoton
# 	- passMetTrigger
# 	- TauEta
# 	- MatchedTruthParticle_isTau
# 	- TauRNNJetScore
# 	- passReco
# 	- TauBaselineWP
# 	- MatchedTruthParticle_isMuon
# 	- TauPt
# 	- MatchedTruthParticle_isElectron
# Calculated Variables:
# 	- MTW
# ----------------------------
#
# Initiating RDataFrame from trees: {'T_s1thv_NOMINAL'}..
# defining variable calculation for: MTW
# Generating filters trees for dataframes...
# Importing dataset 'data' from file: /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/root/data.root...
# Found systematic: T_s1thv_NOMINAL
# 776 histograms and 0 RDataFrames successfully imported into dataset 'data' from file: /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/root/data.root
# ==============================================
# ========= DATASET 'data' INITIALISED =========
# ==============================================
#
#
# ================================================
# ======== INITIALISING DATASET 'wtaunu' =========
# ================================================
#
# DEBUG DATASET OPTIONS:
# ----------------------------
# Input ROOT file(s):  {'lm_cut': PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_Wtaunu_*_maxHTpTV2*/*.root'), 'full': PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_Wtaunu_mW_120*/*.root')}
# Hard cut(s) applied: {'lm_cut': 'TruthBosonM < 120'}
# Defined subsamples:
# 	- full
# 	- lm_cut
# Defined systematics:
# 	- T_s1thv_NOMINAL
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1up
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1down
# 	- TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1down
# 	- TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1up
# 	- TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1up
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1up
# Defined TTree(s): {'T_s1thv_NOMINAL'}
# Variables to pull from files:
# 	- TauPhi
# 	- TauNCoreTracks
# 	- MET_met
# 	- TauCharge
# 	- TauBDTEleScore
# 	- MET_phi
# 	- MatchedTruthParticle_isPhoton
# 	- passMetTrigger
# 	- TauEta
# 	- MatchedTruthParticle_isTau
# 	- TauRNNJetScore
# 	- TruthBosonM
# 	- passReco
# 	- TauBaselineWP
# 	- MatchedTruthParticle_isMuon
# 	- TauPt
# 	- MatchedTruthParticle_isElectron
# 	- MatchedTruthParticle_isHadronicTau
# Calculated Variables:
# 	- MTW
# ----------------------------
#
# Initiating RDataFrame from trees: {'T_s1thv_NOMINAL'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1up'}..
# defining variable calculation for: MTW
# Generating filters trees for dataframes...
# Initialised dataset: wtaunu
# Importing dataset 'wtaunu' from file: /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/root/wtaunu.root...
# Found systematic: T_s1thv_NOMINAL
# Found systematic: TAUS_TRUEHADTAU_EFF_ELEOLR_TOTAL__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_ELEOLR_TOTAL__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETAHIGH_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETAHIGH_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETALOW_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETALOW_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETAHIGH_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETAHIGH_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETALOW_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETALOW_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_HIGHPT_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_HIGHPT_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_SYST_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_SYST_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RECO_TOTAL__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RECO_TOTAL__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_1PRONGSTATSYSTPTGE40__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_1PRONGSTATSYSTPTGE40__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_3PRONGSTATSYSTPTGE40__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_3PRONGSTATSYSTPTGE40__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_HIGHPT__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_HIGHPT__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_SYST__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_SYST__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATDATA161718__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATDATA161718__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATMC161718__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATMC161718__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_SYST161718__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_SYST161718__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1up
# 263655 histograms and 0 RDataFrames successfully imported into dataset 'wtaunu' from file: /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/root/wtaunu.root
# ================================================
# ========= DATASET 'wtaunu' INITIALISED =========
# ================================================
#
#
# ==============================================
# ======== INITIALISING DATASET 'wlnu' =========
# ==============================================
#
# DEBUG DATASET OPTIONS:
# ----------------------------
# Input ROOT file(s):  {'lm_cut': [PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_Wmunu_maxHTpTV2*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_Wenu_maxHTpTV2*/*.root')], 'full': [PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_Wmunu_mW_120*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_Wenu_mW_120*/*.root')]}
# Hard cut(s) applied: {'lm_cut': 'TruthBosonM < 120'}
# Defined subsamples:
# 	- full
# 	- lm_cut
# Defined systematics:
# 	- T_s1thv_NOMINAL
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1up
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1down
# 	- TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1down
# 	- TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1up
# 	- TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1up
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1up
# Defined TTree(s): {'T_s1thv_NOMINAL'}
# Variables to pull from files:
# 	- TauPhi
# 	- TauNCoreTracks
# 	- MET_met
# 	- TauCharge
# 	- TauBDTEleScore
# 	- MET_phi
# 	- MatchedTruthParticle_isPhoton
# 	- passMetTrigger
# 	- TauEta
# 	- MatchedTruthParticle_isTau
# 	- TauRNNJetScore
# 	- TruthBosonM
# 	- passReco
# 	- TauBaselineWP
# 	- MatchedTruthParticle_isMuon
# 	- TauPt
# 	- MatchedTruthParticle_isElectron
# 	- MatchedTruthParticle_isHadronicTau
# Calculated Variables:
# 	- MTW
# ----------------------------
#
# Initiating RDataFrame from trees: {'T_s1thv_NOMINAL'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1up'}..
# defining variable calculation for: MTW
# Generating filters trees for dataframes...
# Initialised dataset: wlnu
# Importing dataset 'wlnu' from file: /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/root/wlnu.root...
# Found systematic: T_s1thv_NOMINAL
# Found systematic: TAUS_TRUEHADTAU_EFF_ELEOLR_TOTAL__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_ELEOLR_TOTAL__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETAHIGH_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETAHIGH_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETALOW_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETALOW_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETAHIGH_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETAHIGH_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETALOW_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETALOW_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_HIGHPT_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_HIGHPT_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_SYST_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_SYST_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RECO_TOTAL__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RECO_TOTAL__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_1PRONGSTATSYSTPTGE40__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_1PRONGSTATSYSTPTGE40__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_3PRONGSTATSYSTPTGE40__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_3PRONGSTATSYSTPTGE40__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_HIGHPT__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_HIGHPT__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_SYST__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_SYST__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATDATA161718__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATDATA161718__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATMC161718__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATMC161718__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_SYST161718__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_SYST161718__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1up
# 263655 histograms and 0 RDataFrames successfully imported into dataset 'wlnu' from file: /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/root/wlnu.root
# ==============================================
# ========= DATASET 'wlnu' INITIALISED =========
# ==============================================
#
#
# =============================================
# ======== INITIALISING DATASET 'zll' =========
# =============================================
#
# DEBUG DATASET OPTIONS:
# ----------------------------
# Input ROOT file(s):  {'lm_cut': [PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_Ztautau_*_maxHTpTV2*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_Zee_maxHTpTV2*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_Zmumu_maxHTpTV2*/*.root')], 'full': [PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_Ztautau_mZ_120*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_Zmumu_mZ_120*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_Zee_mZ_120*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_Znunu_pTV2*/*.root')]}
# Hard cut(s) applied: {'lm_cut': 'TruthBosonM < 120'}
# Defined subsamples:
# 	- full
# 	- lm_cut
# Defined systematics:
# 	- T_s1thv_NOMINAL
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1up
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1down
# 	- TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1down
# 	- TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1up
# 	- TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1up
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1up
# Defined TTree(s): {'T_s1thv_NOMINAL'}
# Variables to pull from files:
# 	- TauPhi
# 	- TauNCoreTracks
# 	- MET_met
# 	- TauCharge
# 	- TauBDTEleScore
# 	- MET_phi
# 	- MatchedTruthParticle_isPhoton
# 	- passMetTrigger
# 	- TauEta
# 	- MatchedTruthParticle_isTau
# 	- TauRNNJetScore
# 	- TruthBosonM
# 	- passReco
# 	- TauBaselineWP
# 	- MatchedTruthParticle_isMuon
# 	- TauPt
# 	- MatchedTruthParticle_isElectron
# 	- MatchedTruthParticle_isHadronicTau
# Calculated Variables:
# 	- MTW
# ----------------------------
#
# Initiating RDataFrame from trees: {'T_s1thv_NOMINAL'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1up'}..
# defining variable calculation for: MTW
# Generating filters trees for dataframes...
# Initialised dataset: zll
# Importing dataset 'zll' from file: /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/root/zll.root...
# Found systematic: T_s1thv_NOMINAL
# Found systematic: TAUS_TRUEHADTAU_EFF_ELEOLR_TOTAL__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_ELEOLR_TOTAL__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETAHIGH_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETAHIGH_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETALOW_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETALOW_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETAHIGH_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETAHIGH_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETALOW_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETALOW_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_HIGHPT_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_HIGHPT_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_SYST_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_SYST_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RECO_TOTAL__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RECO_TOTAL__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_1PRONGSTATSYSTPTGE40__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_1PRONGSTATSYSTPTGE40__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_3PRONGSTATSYSTPTGE40__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_3PRONGSTATSYSTPTGE40__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_HIGHPT__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_HIGHPT__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_SYST__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_SYST__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATDATA161718__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATDATA161718__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATMC161718__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATMC161718__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_SYST161718__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_SYST161718__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1up
# 263655 histograms and 0 RDataFrames successfully imported into dataset 'zll' from file: /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/root/zll.root
# =============================================
# ========= DATASET 'zll' INITIALISED =========
# =============================================
#
#
# =============================================
# ======== INITIALISING DATASET 'top' =========
# =============================================
#
# DEBUG DATASET OPTIONS:
# ----------------------------
# Input ROOT file(s):  {'default': [PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*PP8_singletop*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*PP8_tchan*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*PP8_Wt_DR_dilepton*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*PP8_ttbar_hdamp258p75*/*.root')]}
# Hard cut(s) applied: {}
# Defined subsamples:
# 	- default
# Defined systematics:
# 	- T_s1thv_NOMINAL
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1up
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1down
# 	- TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1down
# 	- TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1up
# 	- TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1up
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1up
# Defined TTree(s): {'T_s1thv_NOMINAL'}
# Variables to pull from files:
# 	- TauPhi
# 	- TauNCoreTracks
# 	- MET_met
# 	- TauCharge
# 	- TauBDTEleScore
# 	- MET_phi
# 	- MatchedTruthParticle_isPhoton
# 	- passMetTrigger
# 	- TauEta
# 	- MatchedTruthParticle_isTau
# 	- TauRNNJetScore
# 	- passReco
# 	- TauBaselineWP
# 	- MatchedTruthParticle_isMuon
# 	- TauPt
# 	- MatchedTruthParticle_isElectron
# 	- MatchedTruthParticle_isHadronicTau
# Calculated Variables:
# 	- MTW
# ----------------------------
#
# Initiating RDataFrame from trees: {'T_s1thv_NOMINAL'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1up'}..
# defining variable calculation for: MTW
# Generating filters trees for dataframes...
# Initialised dataset: top
# Importing dataset 'top' from file: /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/root/top.root...
# Found systematic: T_s1thv_NOMINAL
# Found systematic: TAUS_TRUEHADTAU_EFF_ELEOLR_TOTAL__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_ELEOLR_TOTAL__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETAHIGH_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETAHIGH_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETALOW_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETALOW_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETAHIGH_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETAHIGH_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETALOW_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETALOW_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_HIGHPT_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_HIGHPT_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_SYST_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_SYST_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RECO_TOTAL__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RECO_TOTAL__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_1PRONGSTATSYSTPTGE40__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_1PRONGSTATSYSTPTGE40__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_3PRONGSTATSYSTPTGE40__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_3PRONGSTATSYSTPTGE40__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_HIGHPT__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_HIGHPT__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_SYST__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_SYST__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATDATA161718__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATDATA161718__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATMC161718__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATMC161718__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_SYST161718__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_SYST161718__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1up
# 262363 histograms and 0 RDataFrames successfully imported into dataset 'top' from file: /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/root/top.root
# =============================================
# ========= DATASET 'top' INITIALISED =========
# =============================================
#
#
# =================================================
# ======== INITIALISING DATASET 'diboson' =========
# =================================================
#
# DEBUG DATASET OPTIONS:
# ----------------------------
# Input ROOT file(s):  {'default': [PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2212_llll*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2212_lllv*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2212_llvv*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2212_lvvv*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2212_vvvv*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_ZqqZll*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_ZbbZll*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_WqqZll*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_WlvWqq*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_WlvZqq*/*.root'), PosixPath('/mnt/D/data/DTA_outputs/2024-09-19/*Sh_2211_WlvZbb*/*.root')]}
# Hard cut(s) applied: {}
# Defined subsamples:
# 	- default
# Defined systematics:
# 	- T_s1thv_NOMINAL
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1up
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1down
# 	- TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1down
# 	- TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1up
# 	- TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1up
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down
# 	- TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up
# 	- TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1up
# Defined TTree(s): {'T_s1thv_NOMINAL'}
# Variables to pull from files:
# 	- TauPhi
# 	- TauNCoreTracks
# 	- MET_met
# 	- TauCharge
# 	- TauBDTEleScore
# 	- MET_phi
# 	- MatchedTruthParticle_isPhoton
# 	- passMetTrigger
# 	- TauEta
# 	- MatchedTruthParticle_isTau
# 	- TauRNNJetScore
# 	- passReco
# 	- TauBaselineWP
# 	- MatchedTruthParticle_isMuon
# 	- TauPt
# 	- MatchedTruthParticle_isElectron
# 	- MatchedTruthParticle_isHadronicTau
# Calculated Variables:
# 	- MTW
# ----------------------------
#
# Initiating RDataFrame from trees: {'T_s1thv_NOMINAL'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up'}..
# defining variable calculation for: MTW
# Initiating RDataFrame from trees: {'T_s1thv_TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1up'}..
# defining variable calculation for: MTW
# Generating filters trees for dataframes...
# Initialised dataset: diboson
# Importing dataset 'diboson' from file: /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/root/diboson.root...
# Found systematic: T_s1thv_NOMINAL
# Found systematic: TAUS_TRUEHADTAU_EFF_ELEOLR_TOTAL__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_ELEOLR_TOTAL__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETAHIGH_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETAHIGH_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETALOW_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_1PRONGSTATSYSTETALOW_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETAHIGH_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETAHIGH_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETALOW_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_3PRONGSTATSYSTETALOW_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_HIGHPT_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_HIGHPT_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_SYST_1down
# Found systematic: TAUS_TRUEHADTAU_EFF_JETID_SYST_1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RECO_TOTAL__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RECO_TOTAL__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_1PRONGSTATSYSTPTGE40__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_1PRONGSTATSYSTPTGE40__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_3PRONGSTATSYSTPTGE40__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_3PRONGSTATSYSTPTGE40__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_HIGHPT__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_HIGHPT__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_SYST__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_RNNID_SYST__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATDATA161718__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATDATA161718__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATMC161718__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_STATMC161718__1up
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_SYST161718__1down
# Found systematic: TAUS_TRUEHADTAU_EFF_TRIGGER_SYST161718__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUEXP__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_MODEL_CLOSURE__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_INSITUFIT__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1down
# Found systematic: TAUS_TRUEHADTAU_SME_TES_PHYSICSLIST__1up
# 262363 histograms and 0 RDataFrames successfully imported into dataset 'diboson' from file: /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/root/diboson.root
# =================================================
# ========= DATASET 'diboson' INITIALISED =========
# =================================================
#
# ====================================
# ANALYSIS 'analysis_main' INITIALISED
# Calculating systematic uncertainties...
# Done.
# Calculating systematic uncertainties...
# Done.
# Calculating systematic uncertainties...
# Done.
# Calculating systematic uncertainties...
# Done.
# Calculating systematic uncertainties...
# Done.

# %%
import matplotlib.pyplot as plt

from utils.helper_functions import get_base_sys_name
from utils.variable_names import variable_data

for wp in ("loose", "medium", "tight"):
    wp_dir = base_plotting_dir / wp


    # SYSTEMATIC UNCERTAINTIES
    # ===========================================================================

    def strip_sys_prefix(s: str) -> str:
        """remove prefix from sys names"""
        return s.removeprefix("TAUS_TRUEHADTAU_").removeprefix("TES_").removeprefix("EFF_")


    # list of systematic variations
    sys_list_eff = sorted(set(get_base_sys_name(s) for s in analysis["wtaunu"].eff_sys_set))
    sys_list_tes = sorted(set(get_base_sys_name(s) for s in analysis["wtaunu"].tes_sys_set))
    cmap = plt.get_cmap("jet")
    colours_eff = [tuple(c) for c in cmap(np.linspace(0, 1.0, len(sys_list_eff)))]
    colours_tes = [tuple(c) for c in cmap(np.linspace(0, 1.0, len(sys_list_tes)))]
    selection = f"{wp}_SR_passID"

    # for each sample
    for mc_sample in mc_samples:
        default_args = {
            "do_stat": False,
            "do_syst": False,
            "ratio_plot": False,
            "ratio_err": None,
            "logy": False,
            "legend_params": {"ncols": 1, "fontsize": 8},
            "title": (
                f"{datasets[mc_sample]['label']} | "
                f"Signal Region | "
                f"2017 | "
                f"{analysis.global_lumi / 1000:.3g}fb$^{{-1}}$"
            )
        }
        analysis.paths.plot_dir = wp_dir / "systematics" / mc_sample

        # mass variables
        ylabel = "Percentage uncertainty / %"
        for v in measurement_vars:
            if v in measurement_vars_mass:
                default_args.update(
                    {"logx": True, "xlabel": variable_data[v]["name"] + " [GeV]"}
                )
            elif v in measurement_vars_unitless:
                default_args.update({"logx": False, "xlabel": variable_data[v]["name"]})

            default_args = {
                "do_stat": False,
                "do_syst": False,
                "ratio_plot": False,
                "ratio_err": None,
                "logy": False,
                "legend_params": {"ncols": 1, "fontsize": 8},
                "title": (
                    f"{datasets[mc_sample]['label']} | "
                    f"Signal Region | "
                    f"2017 | "
                    f"{analysis.global_lumi / 1000:.3g}fb$^{{-1}}$"
                )
            }
            analysis.paths.plot_dir = wp_dir / "systematics" / mc_sample

            analysis.plot(
                val=[
                    analysis[mc_sample].get_hist(
                        variable=f"{v}_{sys_name}_pct_uncert",
                        systematic=NOMINAL_NAME,
                        selection=selection,
                    )
                    for sys_name in sys_list_eff
                ],
                label=[strip_sys_prefix(sys) for sys in sys_list_eff],
                ylabel=ylabel,
                colour=colours_eff,
                **default_args,
                filename=f"{v}_sys_eff_pct_uncert_liny.png",
            )
            analysis.plot(
                val=[
                    analysis[mc_sample].get_hist(
                        variable=f"{v}_{sys_name}_pct_uncert",
                        systematic=NOMINAL_NAME,
                        selection=selection,
                    )
                    for sys_name in sys_list_tes
                ],
                label=[strip_sys_prefix(sys) for sys in sys_list_tes],
                ylabel=ylabel,
                colour=colours_tes,
                **default_args,
                filename=f"{v}_sys_tes_pct_uncert_liny.png",
            )

            # detector systematics
            default_args.update(
                {
                    "selection": f"{wp}_SR_passID",
                    "dataset": mc_sample,
                    "ratio_plot": True,
                    "ratio_label": "sys/nominal",
                    "ratio_axlim": (0.8, 1.2),
                    "logx": True if v in measurement_vars_mass else False
                }
            )
            analysis.plot(
                val=v,
                systematic=[
                    NOMINAL_NAME,
                    "TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up",
                    "TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down",
                    "TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up",
                    "TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down",
                    "TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up",
                    "TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down",
                    "TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up",
                    "TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down",
                ],
                label=[
                    "Nominal",
                    "Endcap_LowPt__1up",
                    "Endcap_LowPt__1down",
                    "Endcap_HighPt__1up",
                    "Endcap_HighPt__1down",
                    "Barrel_LowPt__1up",
                    "Barrel_LowPt__1down",
                    "Barrel_HighPt__1up",
                    "Barrel_HighPt__1down",
                ],
                colour=[
                    "k",
                    (0.0, 0.0, 0.5, 1.0),
                    (0.0, 0.0, 0.5, 1.0),
                    (0.0, 0.8333333333333334, 1.0, 1.0),
                    (0.0, 0.8333333333333334, 1.0, 1.0),
                    (1.0, 0.9012345679012348, 0.0, 1.0),
                    (1.0, 0.9012345679012348, 0.0, 1.0),
                    (0.5, 0.0, 0.0, 1.0),
                    (0.5, 0.0, 0.0, 1.0),
                ],
                linestyle=[
                    "solid",
                    "solid",
                    "dotted",
                    "solid",
                    "dotted",
                    "solid",
                    "dotted",
                    "solid",
                    "dotted",
                ],
                **default_args,
                filename=f"{v}_sys_DETECTOR.png",
            )
            # JETID systematics
            analysis.plot(
                val=v,
                systematic=[
                    NOMINAL_NAME,
                    "TAUS_TRUEHADTAU_EFF_RNNID_SYST__1up",
                    "TAUS_TRUEHADTAU_EFF_RNNID_SYST__1down",
                    "TAUS_TRUEHADTAU_EFF_RNNID_HIGHPT__1up",
                    "TAUS_TRUEHADTAU_EFF_RNNID_HIGHPT__1down",
                    "TAUS_TRUEHADTAU_EFF_RNNID_3PRONGSTATSYSTPTGE40__1up",
                    "TAUS_TRUEHADTAU_EFF_RNNID_3PRONGSTATSYSTPTGE40__1down",
                    "TAUS_TRUEHADTAU_EFF_RNNID_3PRONGSTATSYSTPTGE40__1up",
                    "TAUS_TRUEHADTAU_EFF_RNNID_1PRONGSTATSYSTPTGE40__1down",
                ],
                label=[
                    "Nominal",
                    "SYST__1up",
                    "SYST__1down",
                    "HIGHPT__1up",
                    "HIGHPT__1down",
                    "3PRONGSTATSYSTPTGE40__1up",
                    "3PRONGSTATSYSTPTGE40__1down",
                    "1PRONGSTATSYSTPTGE40__1up",
                    "1PRONGSTATSYSTPTGE40__1down",
                ],
                colour=[
                    "k",
                    (0.0, 0.0, 0.5, 1.0),
                    (0.0, 0.0, 0.5, 1.0),
                    (0.0, 0.8333333333333334, 1.0, 1.0),
                    (0.0, 0.8333333333333334, 1.0, 1.0),
                    (1.0, 0.9012345679012348, 0.0, 1.0),
                    (1.0, 0.9012345679012348, 0.0, 1.0),
                    (0.5, 0.0, 0.0, 1.0),
                    (0.5, 0.0, 0.0, 1.0),
                ],
                linestyle=[
                    "solid",
                    "solid",
                    "dotted",
                    "solid",
                    "dotted",
                    "solid",
                    "dotted",
                    "solid",
                    "dotted",
                ],
                **default_args,
                filename=f"{v}_sys_RNNID.png",
            )
            # TRIGGER systematics
            analysis.plot(
                val=v,
                systematic=[
                    NOMINAL_NAME,
                    "TAUS_TRUEHADTAU_EFF_TRIGGER_SYST161718__1up",
                    "TAUS_TRUEHADTAU_EFF_TRIGGER_SYST161718__1down",
                    "TAUS_TRUEHADTAU_EFF_TRIGGER_STATMC161718__1up",
                    "TAUS_TRUEHADTAU_EFF_TRIGGER_STATMC161718__1down",
                    "TAUS_TRUEHADTAU_EFF_TRIGGER_STATDATA161718__1up",
                    "TAUS_TRUEHADTAU_EFF_TRIGGER_STATDATA161718__1down",
                ],
                label=[
                    "Nominal",
                    "TRIGGER_SYST161718__1up",
                    "TRIGGER_SYST161718__1down",
                    "TRIGGER_STATMC161718_1up",
                    "TRIGGER_STATMC161718_1down",
                    "TRIGGER_STATDATA161718__1up",
                    "TRIGGER_STATDATA161718__1down",
                ],
                colour=[
                    "k",
                    (0.0, 0.0, 0.5, 1.0),
                    (0.0, 0.0, 0.5, 1.0),
                    (0.4901960784313725, 1.0, 0.4775458570524984, 1.0),
                    (0.4901960784313725, 1.0, 0.4775458570524984, 1.0),
                    (0.5, 0.0, 0.0, 1.0),
                    (0.5, 0.0, 0.0, 1.0),
                ],
                linestyle=[
                    "solid",
                    "solid",
                    "dotted",
                    "solid",
                    "dotted",
                    "solid",
                    "dotted",
                ],
                **default_args,
                filename=f"{v}_sys_TRIGGER.png",
            )
# Out:
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauEta_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauEta_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauEta_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauEta_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauEta_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauPhi_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauPhi_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauPhi_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauPhi_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauPhi_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauBDTEleScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauBDTEleScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauBDTEleScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauBDTEleScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauBDTEleScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauRNNJetScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauRNNJetScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauRNNJetScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauRNNJetScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauRNNJetScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauNCoreTracks_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauNCoreTracks_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauNCoreTracks_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauNCoreTracks_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauNCoreTracks_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauPt_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauPt_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauPt_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauPt_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/TauPt_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/MTW_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/MTW_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/MTW_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/MTW_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/MTW_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/MET_met_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/MET_met_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/MET_met_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/MET_met_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wtaunu/MET_met_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauEta_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauEta_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauEta_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauEta_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauEta_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauPhi_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauPhi_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauPhi_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauPhi_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauPhi_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauBDTEleScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauBDTEleScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauBDTEleScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauBDTEleScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauBDTEleScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauRNNJetScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauRNNJetScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauRNNJetScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauRNNJetScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauRNNJetScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauNCoreTracks_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauNCoreTracks_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauNCoreTracks_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauNCoreTracks_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauNCoreTracks_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauPt_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauPt_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauPt_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauPt_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/TauPt_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/MTW_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/MTW_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/MTW_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/MTW_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/MTW_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/MET_met_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/MET_met_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/MET_met_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/MET_met_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/wlnu/MET_met_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauEta_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauEta_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauEta_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauEta_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauEta_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauPhi_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauPhi_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauPhi_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauPhi_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauPhi_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauBDTEleScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauBDTEleScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauBDTEleScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauBDTEleScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauBDTEleScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauRNNJetScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauRNNJetScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauRNNJetScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauRNNJetScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauRNNJetScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauNCoreTracks_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauNCoreTracks_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauNCoreTracks_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauNCoreTracks_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauNCoreTracks_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauPt_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauPt_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauPt_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauPt_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/TauPt_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/MTW_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/MTW_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/MTW_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/MTW_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/MTW_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/MET_met_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/MET_met_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/MET_met_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/MET_met_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/zll/MET_met_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauEta_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauEta_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauEta_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauEta_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauEta_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauPhi_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauPhi_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauPhi_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauPhi_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauPhi_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauBDTEleScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauBDTEleScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauBDTEleScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauBDTEleScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauBDTEleScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauRNNJetScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauRNNJetScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauRNNJetScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauRNNJetScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauRNNJetScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauNCoreTracks_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauNCoreTracks_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauNCoreTracks_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauNCoreTracks_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauNCoreTracks_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauPt_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauPt_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauPt_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauPt_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/TauPt_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/MTW_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/MTW_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/MTW_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/MTW_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/MTW_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/MET_met_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/MET_met_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/MET_met_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/MET_met_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/top/MET_met_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauEta_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauEta_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauEta_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauEta_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauEta_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauPhi_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauPhi_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauPhi_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauPhi_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauPhi_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauBDTEleScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauBDTEleScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauBDTEleScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauBDTEleScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauBDTEleScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauRNNJetScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauRNNJetScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauRNNJetScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauRNNJetScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauRNNJetScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauNCoreTracks_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauNCoreTracks_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauNCoreTracks_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauNCoreTracks_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauNCoreTracks_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauPt_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauPt_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauPt_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauPt_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/TauPt_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/MTW_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/MTW_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/MTW_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/MTW_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/MTW_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/MET_met_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/MET_met_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/MET_met_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/MET_met_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/loose/systematics/diboson/MET_met_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauEta_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauEta_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauEta_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauEta_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauEta_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauPhi_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauPhi_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauPhi_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauPhi_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauPhi_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauBDTEleScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauBDTEleScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauBDTEleScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauBDTEleScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauBDTEleScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauRNNJetScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauRNNJetScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauRNNJetScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauRNNJetScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauRNNJetScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauNCoreTracks_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauNCoreTracks_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauNCoreTracks_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauNCoreTracks_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauNCoreTracks_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauPt_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauPt_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauPt_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauPt_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauPt_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/MTW_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/MTW_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/MTW_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/MTW_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/MTW_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/MET_met_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/MET_met_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/MET_met_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/MET_met_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/MET_met_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauEta_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauEta_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauEta_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauEta_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauEta_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauPhi_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauPhi_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauPhi_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauPhi_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauPhi_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauBDTEleScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauBDTEleScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauBDTEleScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauBDTEleScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauBDTEleScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauRNNJetScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauRNNJetScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauRNNJetScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauRNNJetScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauRNNJetScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauNCoreTracks_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauNCoreTracks_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauNCoreTracks_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauNCoreTracks_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauNCoreTracks_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauPt_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauPt_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauPt_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauPt_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/TauPt_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/MTW_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/MTW_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/MTW_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/MTW_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/MTW_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/MET_met_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/MET_met_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/MET_met_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/MET_met_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wlnu/MET_met_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauEta_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauEta_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauEta_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauEta_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauEta_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauPhi_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauPhi_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauPhi_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauPhi_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauPhi_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauBDTEleScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauBDTEleScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauBDTEleScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauBDTEleScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauBDTEleScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauRNNJetScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauRNNJetScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauRNNJetScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauRNNJetScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauRNNJetScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauNCoreTracks_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauNCoreTracks_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauNCoreTracks_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauNCoreTracks_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/zll/TauNCoreTracks_sys_TRIGGER.png
# ...
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/TauRNNJetScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/TauRNNJetScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/TauNCoreTracks_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/TauNCoreTracks_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/TauNCoreTracks_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/TauNCoreTracks_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/TauNCoreTracks_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/TauPt_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/TauPt_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/TauPt_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/TauPt_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/TauPt_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/MTW_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/MTW_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/MTW_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/MTW_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/MTW_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/MET_met_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/MET_met_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/MET_met_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/MET_met_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/zll/MET_met_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauEta_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauEta_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauEta_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauEta_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauEta_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauPhi_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauPhi_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauPhi_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauPhi_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauPhi_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauBDTEleScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauBDTEleScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauBDTEleScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauBDTEleScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauBDTEleScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauRNNJetScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauRNNJetScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauRNNJetScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauRNNJetScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauRNNJetScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauNCoreTracks_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauNCoreTracks_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauNCoreTracks_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauNCoreTracks_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauNCoreTracks_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauPt_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauPt_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauPt_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauPt_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/TauPt_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/MTW_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/MTW_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/MTW_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/MTW_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/MTW_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/MET_met_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/MET_met_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/MET_met_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/MET_met_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/top/MET_met_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauEta_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauEta_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauEta_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauEta_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauEta_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauPhi_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauPhi_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauPhi_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauPhi_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauPhi_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauBDTEleScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauBDTEleScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauBDTEleScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauBDTEleScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauBDTEleScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauRNNJetScore_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauRNNJetScore_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauRNNJetScore_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauRNNJetScore_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauRNNJetScore_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauNCoreTracks_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauNCoreTracks_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauNCoreTracks_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauNCoreTracks_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauNCoreTracks_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauPt_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauPt_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauPt_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauPt_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/TauPt_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/MTW_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/MTW_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/MTW_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/MTW_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/MTW_sys_TRIGGER.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/MET_met_sys_eff_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/MET_met_sys_tes_pct_uncert_liny.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/MET_met_sys_DETECTOR.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/MET_met_sys_RNNID.png
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/tight/systematics/diboson/MET_met_sys_TRIGGER.png

# %%
analysis.paths.plot_dir = base_plotting_dir / "medium" / "systematics" / "wtaunu"
default_args = {
    "do_stat": False,
    "do_syst": False,
    "ratio_plot": False,
    "ratio_err": None,
    "logy": False,
    "logx": True,
    "legend_params": {"ncols": 1, "fontsize": 8},
    "title": (
        f"{datasets['wtaunu']['label']} | "
        f"Signal Region | "
        f"2017 | "
        f"{analysis.global_lumi / 1000:.3g}fb$^{{-1}}$"
    )
}
val = [
    analysis["wtaunu"].get_hist(
        variable=f"MTW_{sys_name}_pct_uncert",
        systematic=NOMINAL_NAME,
        selection="medium_SR_passID",
    ).Rebin()
    for sys_name in sys_list_eff
]

analysis.plot(
    val=val,
    label=[strip_sys_prefix(sys) for sys in sys_list_eff],
    ylabel="Percentage Uncertainty [%]",
    colour=colours_eff,
    **default_args,
    filename="MTW_sys_eff_pct_uncert_liny.png",
)
# Out:
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/MET_met_sys_eff_pct_uncert_liny.png

# %%
analysis.paths.plot_dir = base_plotting_dir / "medium" / "systematics" / "wtaunu"
default_args = {
    "do_stat": False,
    "do_syst": False,
    "ratio_plot": False,
    "ratio_err": None,
    "logy": False,
    "logx": True,
    "legend_params": {"ncols": 1, "fontsize": 8},
    "title": (
        f"{datasets['wtaunu']['label']} | "
        f"Signal Region | "
        f"2017 | "
        f"{analysis.global_lumi / 1000:.3g}fb$^{{-1}}$"
    )
}
default_args.update(
    {
        "selection": "medium_SR_passID",
        "dataset": "wtaunu",
        "ratio_plot": True,
        "ratio_label": "sys/nominal",
        "ratio_axlim": (0.8, 1.2),
    }
)
analysis.plot(
    val="TauPt",
    systematic=[
        NOMINAL_NAME,
        "TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1up",
        "TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_LowPt__1down",
        "TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1up",
        "TAUS_TRUEHADTAU_SME_TES_DETECTOR_Endcap_HighPt__1down",
        "TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1up",
        "TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_LowPt__1down",
        "TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1up",
        "TAUS_TRUEHADTAU_SME_TES_DETECTOR_Barrel_HighPt__1down",
    ],
    label=[
        "Nominal",
        "Endcap_LowPt__1up",
        "Endcap_LowPt__1down",
        "Endcap_HighPt__1up",
        "Endcap_HighPt__1down",
        "Barrel_LowPt__1up",
        "Barrel_LowPt__1down",
        "Barrel_HighPt__1up",
        "Barrel_HighPt__1down",
    ],
    colour=[
        "k",
        (0.0, 0.0, 0.5, 1.0),
        (0.0, 0.0, 0.5, 1.0),
        (0.0, 0.8333333333333334, 1.0, 1.0),
        (0.0, 0.8333333333333334, 1.0, 1.0),
        (1.0, 0.9012345679012348, 0.0, 1.0),
        (1.0, 0.9012345679012348, 0.0, 1.0),
        (0.5, 0.0, 0.0, 1.0),
        (0.5, 0.0, 0.0, 1.0),
    ],
    linestyle=[
        "solid",
        "solid",
        "dotted",
        "solid",
        "dotted",
        "solid",
        "dotted",
        "solid",
        "dotted",
    ],
    **default_args,
    filename="TauPt_sys_DETECTOR.png",
)
# Out:
# Saved plot to /home/keanu/Uni_Stuff_Queen_Mary/Python_Projects/myFramework/outputs/analysis_main/plots/medium/systematics/wtaunu/TauPt_sys_DETECTOR.png
